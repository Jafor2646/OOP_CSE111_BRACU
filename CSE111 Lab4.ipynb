# %%
#Task 1
class Customer:
  def __init__(self, n):
    self.name = n
  def greet(self, n = ''):
    print(f"Hello!" if n == '' else f"Hello {n}!")
  def purchase(self, *args):
    print(self.name + ",","you purchased",len(args),"item(s):")
    for i in args:
      print(i)

customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")

# Hello!
# Sam, you purchased 3 item(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David, you purchased 1 item(s):
# orange juice
# Out:
# Hello!
# Sam, you purchased 3 item(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David, you purchased 1 item(s):
# orange juice

# %%
#Task 2
class Panda:
    def __init__(self,n,g,a):
        self.name = n
        self.gender = g
        self.age = a
    def sleep(self,time = None):
        if time == None:
            return f"{self.name}'s duration is unknown thus should have only  bamboo leaves"
        elif time >=3 and time<=5:
            return f'{self.name} sleeps {time} hours daily and should have Mixed Veggies'
        elif time >=6 and time<=8:
            return f'{self.name} sleeps {time} hours daily and should have Eggplant & Tofu'
        elif time>=9 and time<= 11:
            return f'{self.name} sleeps {time} hours daily and should have Broccoli Chicken'

panda1 = Panda("Kunfu","Male", 5) 
panda2=Panda("Pan Pan","Female",3) 
panda3=Panda("Ming Ming","Female",8) 
 
print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age)) 
 
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age)) 
 
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age)) 
print("===========================") 
print(panda2.sleep(10)) 
print(panda1.sleep(4)) 
print(panda3.sleep())
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ===========================
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken 
#Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only bamboo leaves
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ===========================
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only  bamboo leaves

# %%
#Task 3
class Cat:
  def __init__(self, c = "White", w = "sitting"):
    self.color = c
    self.work = w
  def printCat(self):
    print(self.color,"cat is",self.work)
  def changeColor(self, c):
    self.color = c
c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#Task 4
class Student:
  def __init__(self, n = "df"):
    self.name = n
    self.avg = 0
  def quizcalc(self, *args):
    temp = 0
    for i in args:
      temp += i
    self.avg = temp / 3
  def printdetail(self):
    if self.name == "df":
      print("Hello default student")
    else:
      print("Hello",self.name)
    print("Your average quiz score is",self.avg)
s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Hello default student
# Your average quiz score is 3.3333333333333335
# --------------------------------
# Hello Harry
# Your average quiz score is 6.0
# --------------------------------
# Hello Hermione
# Your average quiz score is 9.666666666666666
# Out:
# --------------------------------
# Hello default student
# Your average quiz score is 3.3333333333333335
# --------------------------------
# Hello Harry
# Your average quiz score is 6.0
# --------------------------------
# Hello Hermione
# Your average quiz score is 9.666666666666666

# %%
#Task 5
class Student:
  def __init__(self, n, i, d = "CSE"):
    self.name = n
    self.id = i
    self.dept = d
  def dailyEffort(self, h):
    self.hour = h
    self.sug = None
    if self.hour <= 2:
      self.sug = "Should give more effort!"
    elif self.hour <= 4:
      self.sug = "Keep up the good work!"
    else:
      self.sug = "Excellent! Now motivate others."
  def printDetails(self):
    print("Name:",self.name)
    print("ID:",self.id)
    print("Department:",self.dept)
    print("Daily Effort:",self.hour,"hour(s)")
    print("Suggestion:",self.sug)
harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Name: Harry Potter
# ID: 123
# Department: CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ========================
# Name: John Wick
# ID: 456
# Department: BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ========================
# Name: Naruto Uzumaki
# ID: 777
# Department: Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Excellent! Now motivate others.
# Out:
# Name: Harry Potter
# ID: 123
# Department: CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ========================
# Name: John Wick
# ID: 456
# Department: BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ========================
# Name: Naruto Uzumaki
# ID: 777
# Department: Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Excellent! Now motivate others.

# %%
#Task 6
class Patient:
    def __init__(self, n, a):
        self.name = n
        self.age = a
        self.symp = []
    def add_Symptom(self,*sym):
        for item in sym:
            self.symp.append(item)
    def printPatientDetail(self):
        print(f'Name: {self.name}')
        print(f'Age: {self.age}')
        smp=''
        for sym in self.symp:
            smp+= f' {sym},'
        smp=smp[:len(smp)-1]
        print(f'Symptoms:{smp}')
p1 = Patient('Thomas', 23) 
p1.add_Symptom('Headache') 
p2 = Patient('Carol', 20) 
p2.add_Symptom('Vomiting', 'Coughing') 
p3 = Patient('Mike', 25) 
p3.add_Symptom('Fever', 'Headache', 'Coughing') 
print("=========================") 
p1.printPatientDetail() 
print("=========================") 
p2.printPatientDetail() 
print("=========================") 
p3.printPatientDetail() 
# =========================
# Name: Thomas
# Age: 23
# Symptoms: Headache
# =========================
# Name: Carol
# Age: 20
# Symptoms: Vomiting, Coughing
# =========================
# Name: Mike
# Age: 25
# Symptoms: Fever, Headache, Coughing
# Out:
# =========================
# Name: Thomas
# Age: 23
# Symptoms: Headache
# =========================
# Name: Carol
# Age: 20
# Symptoms: Vomiting, Coughing
# =========================
# Name: Mike
# Age: 25
# Symptoms: Fever, Headache, Coughing

# %%
#Task 7
class Match:
  def __init__(self, n):
    self.lst = n.split("-")
    self.run = 0
    self.wick = 0
    self.over = 0
    print("5..4..3..2..1.. play !!!")
  def add_run(self, r):
    self.run += r
  def add_over(self, o):
    self.over += o
    if self.over >= 5:
      print("Warning! Cannot add", o, "over/s (5 over match)")
      self.over -= o
  def add_wicket(self, w):
    self.wick += w
  def print_scoreboard(self):
    temp = "Batting Team: " + self.lst[0] + "\n" + "Bowling Team: " + self.lst[1] + "\n" + "Total  Runs: " + str(self.run) + " Wickets: " + str(self.wick) + " Overs: " + str(self.over)
    return temp  
match1 = Match("Rangpur Riders-Cumilla Victorians")
print("=========================")
match1.add_run(4)
match1.add_run(6)
match1.add_over(1)
print(match1.print_scoreboard())
print("=========================")
match1.add_over(5)
print("=========================")
match1.add_wicket(1)
print(match1.print_scoreboard())
# 5..4..3..2..1.. Play !!!
# ============================
# Batting Team: Rangpur Riders
# Bowling Team: Cumilla Victorians
# Total Runs: 10 Wickets: 0 Overs: 1
# ============================
# Warning! Cannot add 5 over/s (5 over match)
# ============================
# Batting Team: Rangpur Riders
# Bowling Team: Cumilla Victorians
# Total Runs: 10 Wickets: 1 Overs: 1
# Out:
# 5..4..3..2..1.. play !!!
# =========================
# Batting Team: Rangpur Riders
# Bowling Team: Cumilla Victorians
# Total  Runs: 10 Wickets: 0 Overs: 1
# =========================
# Warning! Cannot add 5 over/s (5 over match)
# =========================
# Batting Team: Rangpur Riders
# Bowling Team: Cumilla Victorians
# Total  Runs: 10 Wickets: 1 Overs: 1

# %%
#Task 8
class ParcelKoro:
  def __init__(self, n = "No name set", w = 0):
    self.name = n
    self.product_weight = w
    self.fee = 0
  def calculateFee(self, p = "DF"):
    if self.product_weight == 0:
      self.fee = 0
    elif p == "DF" and self.product_weight != 0:
      self.fee += (self.product_weight*20) + 50
    else:
      self.fee += (self.product_weight*20) + 100
  def printDetails(self):
    print("Customer Name:", self.name)
    print("Product Weight:",self.product_weight)
    print("Total fee:", self.fee)
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer', 10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# **********************
# Customer Name: No name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 15
# Total fee: 350
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300
# Out:
# Customer Name: No name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 15
# Total fee: 350
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %%
#Task 9
class Batsman:
    def __init__(self, n = None, r = None, b = None):
        if b == None:
            self.name = 'New Batsman'
            self.run = n
            self.ball = r
        else:
            self.name = n
            self.run = r
            self.ball = b
    def printCareerStatistics(self):
        print(f'Name: {self.name}')
        print(f'Runs Scored: {self.run} , Balls Faced: {self.ball}')
    def battingStrikeRate(self):
        return (self.run/self.ball)*100
    def setName(self,name):
        self.name=name
b1 = Batsman(6101, 7380) 
b1.printCareerStatistics() 
print("============================") 
b2 = Batsman("Liton Das", 678, 773) 
b2.printCareerStatistics() 
print("----------------------------") 
print(b2.battingStrikeRate()) 
print("============================") 
b1.setName("Shakib Al Hasan") 
b1.printCareerStatistics() 
print("----------------------------") 
print(b1.battingStrikeRate()) 
# Name: New Batsman
# Runs Scored: 6101 , Balls Faced: 7380
# ============================
# Name: Liton Das
# Runs Scored: 678 , Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ============================
# Name: Shakib Al Hasan
# Runs Scored: 6101 , Balls Faced: 7380
# ----------------------------
# 82.66937669376694
# Out:
# Name: New Batsman
# Runs Scored: 6101 , Balls Faced: 7380
# ============================
# Name: Liton Das
# Runs Scored: 678 , Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ============================
# Name: Shakib Al Hasan
# Runs Scored: 6101 , Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#Task 10
class EPL_Team:
  def __init__(self, n, s = "No Slogan"):
    self.name = n
    self.song = s
    self.title = 0
  def showClubInfo(self):
    temp = "Name: " + self.name + "\n" + "Song: " + self.song + "\n" + "Total No of title: " + str(self.title)
    return temp
  def increaseTitle(self):
    self.title += 1
  def changeSong(self, s):
    self.song = s

manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# ===================
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 0
# ##################
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 1
# ===================
# Name: Chelsea
# Song: No Slogan
# Total No of title: 0
# Name: Chelsea
# Song: Keep the blue flag flying high
# Total No of title: 0
# Out:
# ===================
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 0
# ##################
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 1
# ===================
# Name: Chelsea
# Song: No Slogan
# Total No of title: 0
# Name: Chelsea
# Song: Keep the blue flag flying high
# Total No of title: 0

# %%
#Task 11
class Author:
    def __init__ (self,n = 'Default',*args):
        self.name = n 
        self.book=list(args)
    def addBooks(self,*args):
        for book in args:
            self.book.append(book)
    def changeName(self,name):
        self.name=name
    def printDetails(self):
        print("Author Name:", self.name)
        print('--------')
        print('List of Books:')
        for b in self.book:
            print(b)
auth1 = Author('Humayun Ahmed') 
auth1.addBooks('Deyal', 'Megher Opor Bari') 
auth1.printDetails() 
print('===================') 
auth2 = Author() 
print(auth2.name) 
auth2.changeName('Mario Puzo') 
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian') 
print('===================') 
auth2.printDetails() 
print('===================') 
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain') 
auth3.printDetails() 

# Author Name: Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ===================
# Default
# ===================
# Author Name: Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ===================
# Author Name: Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain
# Out:
# Author Name: Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ===================
# Default
# ===================
# Author Name: Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ===================
# Author Name: Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#Task 12
class TaxiLagbe:
  def __init__(self, t, l):
    self.taxiNum = t 
    self.location = l
    self.pas = {}
  def addPassenger(self, *args):
    if len(self.pas) < 4:
      for i in range(len(args)):
        name, fare = args[i].split("_")
        self.pas[name] = fare
        print("Dear", name + "!","Welcome to TaxiLagbe.")
    else:
      print("Taxi Full! No more passengers can be added.")
  def printDetails(self):
    print("Trip info for Taxi number:", self.taxiNum)
    print("This taxi can cover only", self.location,"area.")
    print("Total passengers:", len(self.pas))
    print("Passenger lists:")
    sum = 0
    temp = ""
    for k,v in self.pas.items():
      temp += k + ", "
      sum += int(v)
    print(temp[:len(temp)-2])
    print("Total collected fare:", sum,"Taka") 
taxi1 = TaxiLagbe('1010-01', 'Dhaka') 
print('-------------------------------') 
taxi1.addPassenger('Walker_100', 'Wood_200') 
taxi1.addPassenger('Matt_100') 
taxi1.addPassenger('Wilson_105') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------') 
taxi1.addPassenger('Karen_200') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------') 
taxi2 = TaxiLagbe('1010-02', 'Khulna') 
taxi2.addPassenger('Ronald_115') 
taxi2.addPassenger('Parker_215') 
print('-------------------------------') 
taxi2.printDetails()

# --------------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# --------------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# --------------------------------------
# Taxi Full! No more passengers can be added.
# --------------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# --------------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# --------------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can cover only Khulna area.
# Total passengers: 2
# Passenger lists:
# Ronald, Parker
# Total collected fare: 330 Taka
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can cover only Khulna area.
# Total passengers: 2
# Passenger lists:
# Ronald, Parker
# Total collected fare: 330 Taka

# %%
#Task 12
class TaxiLagbe:
    def __init__(self, c, a):
        self.car_name = c
        self.adress = a
        self.passenger = {}
    def addPassenger(self,*passenger):
        if len(self.passenger)<4:
            for ele in passenger:
                name,fare=self.separator(ele)
                self.passenger[name]=fare
                print(f'Dear {name}! Welcome to TaxiLagbe.')
        else:
            print('Taxi Full! No more passengers can be added.')
    def separator(self,mixed_name):
        idx=0
        for i in mixed_name:
            if i == '_':
                break
            idx+=1
        name=mixed_name[:idx]
        fare=mixed_name[idx+1:]
        return (name,fare)
    def printDetails(self):
        print('Trip info for Taxi number:',self.car_name)
        print(f'This taxi can cover only {self.adress} area.')
        print(f'Total passengers: {len(self.passenger)}')
        print('Passenger lists:')
        sum=0
        str=''
        for key ,value in self.passenger.items():
            str += f'{key}, '
            sum+=int(value)
        print(str[:len(str)-2])
        print(f'Total collected fare: {sum} Taka')
taxi1 = TaxiLagbe('1010-01', 'Dhaka') 
print('-------------------------------') 
taxi1.addPassenger('Walker_100', 'Wood_200') 
taxi1.addPassenger('Matt_100') 
taxi1.addPassenger('Wilson_105') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------') 
taxi1.addPassenger('Karen_200') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------') 
taxi2 = TaxiLagbe('1010-02', 'Khulna') 
taxi2.addPassenger('Ronald_115') 
taxi2.addPassenger('Parker_215') 
print('-------------------------------') 
taxi2.printDetails()

# --------------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# --------------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# --------------------------------------
# Taxi Full! No more passengers can be added.
# --------------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# --------------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# --------------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can cover only Khulna area.
# Total passengers: 2
# Passenger lists:
# Ronald, Parker
# Total collected fare: 330 Taka
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can cover only Khulna area.
# Total passengers: 2
# Passenger lists:
# Ronald, Parker
# Total collected fare: 330 Taka

# %%
#Task 13
class Account:
  def __init__(self, n = "Default Account", b = 0.0):
    self.name = n
    self.balance = b
  def details(self):
    temp = f"{self.name}\n{float(self.balance)}"
    return temp
  def withdraw(self, a):
    self.balance -= a
    if self.balance > 3070:
      print("Withdraw successful! New balance is:", float(self.balance))
    else:
      self.balance += a
      print("Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.")
a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930)
print("------------------------")
a2.withdraw(600)
print("------------------------")
a1.withdraw(6929)
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400.0
# ------------------------
# Sorry, Withdraw unsuccessful! The account
# balance after deducting withdraw amount is
# equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account
# balance after deducting withdraw amount is
# equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is: 3071.0
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400.0
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is: 3071.0

# %%
#Task 14
class StudentDatabase:
    def __init__(self, n, i):
        self.name = n
        self.id = i
        self.grades = {}
    def calculateGPA(self,v,k):
        subjectList = []
        gpa = 0
        subNum = 0
        for i in v:
            subjectList.append(i[:6])
            gpa+= float(i[8:])*3
            subNum+=1
        gpa=float("{:.2f}".format(gpa/(subNum*3)))
        self.grades[k]={tuple(subjectList):gpa}
    def printDetails(self):
        print('Name:',self.name)
        print('ID:',self.id)
        for k,v in self.grades.items():
            print(f'Courses taken in {k}:')
            for i in v.keys():
                for j in i:
                    print(j)
                print(f'GPA: {v[i]}')
s1 = StudentDatabase('Pietro', '10101222') 
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020') 
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021') 
print(f'Grades for {s1.name}\n{s1.grades}') 
print('------------------------------------------------------') 
s1.printDetails() 
s2 = StudentDatabase('Wanda', '10103332') 
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022') 
print('------------------------------------------------------') 
print(f'Grades for {s2.name}\n{s2.grades}') 
print('------------------------------------------------------') 
s2.printDetails()
# Grades for Pietro
#{'Summer2020': {('CSE230', 'CSE220','MAT110'): 4.0}, 'Summer2021':{('CSE250', 'CSE330'): 3.85}}
# -----------------------------------------------
# Name: Pietro
# ID: 10101222
# Courses taken in Summer2020:
# CSE230
# CSE220
# MAT110
# GPA: 4.0
# Courses taken in Summer2021:
# CSE250
# CSE330
# GPA: 3.85
# -----------------------------------------------
# Grades for Wanda
#{'Summer2022': {('CSE111', 'CSE260','ENG101'): 3.8}}
# -----------------------------------------------
# Name: Wanda
# ID: 10103332
# Courses taken in Summer2022:
# CSE111
# CSE260
# ENG101
# GPA: 3.8
# Out:
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ------------------------------------------------------
# Name: Pietro
# ID: 10101222
# Courses taken in Summer2020:
# CSE230
# CSE220
# MAT110
# GPA: 4.0
# Courses taken in Summer2021:
# CSE250
# CSE330
# GPA: 3.85
# ------------------------------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8}}
# ------------------------------------------------------
# Name: Wanda
# ID: 10103332
# Courses taken in Summer2022:
# CSE111
# CSE260
# ENG101
# GPA: 3.8

# %%
class msgClass:
  def __init__(self): 
    self.content = 0
class Q5:
  def __init__(self):
    self.sum = 1
    self.x = 2
    self.y = 3
  def methodA(self):
    x, y = 1, 1
    msg = []
    myMsg = msgClass()
    myMsg.content = self.x
    msg.append(myMsg)
    msg[0].content = self.y + myMsg.content
    self.y = self.y + self.methodB(msg[0])
    y = self.methodB(msg[0]) + self.y
    x = y + self.methodB(msg[0], msg)
    self.sum = x + y + msg[0].content
    print(x," ", y," ", self.sum)
  def methodB(self, mg1, mg2 = None):
    if mg2 == None:
      x, y = 5, 6
      y = self.sum + mg1.content
      self.y = y + mg1.content
      x = self.x + 7 +mg1.content
      self.sum = self.sum + x + y
      self.x = mg1.content + x +8
      print(x, " ", y," ", self.sum)
      return y
    else:
      x = 1
      self.y += mg2[0].content
      mg2[0].content = self.y + mg1.content
      x = x + 4 + mg1.content
      self.sum += x + self.y
      mg1.content = self.sum - mg2[0].content
      print(self.x, " ",self.y," ", self.sum)
      return self.sum
q = Q5()
q.methodA()
# Out:
# 14   6   21
# 39   26   86
# 52   36   168
# 225   57   409

# %%
#Task 20
class Student:
  def __init__(self, n = "df", d = "df"):
    self.name = n
    self.dept = d
    self.crs = []
    if self.name == "df" and self.dept == "df":
      print("Student name and department need to be set")
    elif self.dept == "df":
      print("Department for", self.name,"needs to be set")
    else:
      print(self.name,"is from",self.dept,"department")
  def update_name(self, n):
    self.name = n
  def update_department(self, d):
    self.dept = d
  def enroll(self, *args):
    for i in args:
      self.crs.append(i)
  def printDetail(self):
    print("Name:",self.name)
    print("Department:",self.dept)
    print(self.name,"enrolled in",len(self.crs),"course(s):")
    for i in range(len(self.crs)):
      if i == len(self.crs)-1:
        print(self.crs[i])
      else:
        print(self.crs[i], end=", ")
s1 = Student()
print("=========================")
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110", "MAT110", "ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Student name and department need to be set
# =========================
# Department for Carol needs to be set
# =========================
# Jon is from EEE department
# =========================
# ###########################
# Name: Bob
# Department: CSE
# Bob enrolled in 3 course(s):
# CSE110, MAT110, ENG091
# =========================
# Name: Carol
# Department: BBA
# Carol enrolled in 1 course(s):
# BUS101
# =========================
# Name: Jon
# Department: EEE
# Jon enrolled in 2 course(s):
# MAT110, PHY111
# Out:
# Student name and department need to be set
# =========================
# Department for Carol needs to be set
# =========================
# Jon is from EEE department
# =========================
# ###########################
# Name: Bob
# Department: CSE
# Bob enrolled in 3 course(s):
# CSE110, MAT110, ENG091
# =========================
# Name: Carol
# Department: BBA
# Carol enrolled in 1 course(s):
# BUS101
# =========================
# Name: Jon
# Department: EEE
# Jon enrolled in 2 course(s):
# MAT110, PHY111

# %%
#Task 21
class Student:
  def __init__(self, n, i, d):
    self.name = n
    self.id = i
    self.dept = d
  def details(self):
    temp = f"Name: {self.name}\nID: {self.id}\nDepartment: {self.dept}"
    return temp
  def advise(self, *args):
    count = 0
    print(self.name + ",","you have taken",float(len(args)*3),"credits.")
    print("List of courses:", end="")
    for i in range(len(args)):
      if i == len(args)-1:
        print(args[i])
      else:
        print(args[i], end=", ")
      count += 1
    if count >= 3 and count <= 4:
      print("Status: OK")
    elif count < 3:
      print("Status: You have to take at least",3-len(args),"course")
    elif count > 4:
      print("Status: You have to drop at least",len(args)-4,"course")
s1 = Student("Alice","20103012","CSE")
s2 = Student("Bob", "18301254","EEE")
s3 = Student("Carol", "17101238","CSE")
print("##########################")
print(s1.details())
print("##########################")
print(s2.details())
print("##########################")
s1.advise("CSE110", "MAT110", "PHY111")
print("##########################")
s2.advise("BUS101", "MAT120")
print("##########################")
s3.advise("MAT110", "PHY111", "ENG102","CSE111", "CSE230")
# ##########################
# Name: Alice
# ID: 20103012
# Department: CSE
# ##########################
# Name: Bob
# ID: 18301254
# Department: EEE
# ##########################
# Alice, you have taken 9.0 credits.
# List of courses: CSE110, MAT110, PHY111
# Status: Ok
# ##########################
# Bob, you have taken 6.0 credits.
# List of courses: BUS101, MAT120
# Status: You have to take at least 1 more course.
# ##########################
# Carol, you have taken 15.0 credits.
# List of courses: MAT110, PHY111, ENG102,
# CSE111, CSE230
# Status: You have to drop at least 1 course.
# Out:
# ##########################
# Name: Alice
# ID: 20103012
# Department: CSE
# ##########################
# Name: Bob
# ID: 18301254
# Department: EEE
# ##########################
# Alice, you have taken 9.0 credits.
# List of courses:CSE110, MAT110, PHY111
# Status: OK
# ##########################
# Bob, you have taken 6.0 credits.
# List of courses:BUS101, MAT120
# Status: You have to take at least 1 course
# ##########################
# Carol, you have taken 15.0 credits.
# List of courses:MAT110, PHY111, ENG102, CSE111, CSE230
# Status: You have to drop at least 1 course

# %%
#Task 22
class Hotel:
  def __init__(self, hn):
    self.hotelName = hn
    self.stuffId = 0
    self.stuffName = None
    self.stuffAge = None
    self.stuffContact = None
    self.stuff ={}
    self.guestId = 0
    self.guestName = None
    self.guestAge = None
    self.guestContact = None
    self.guest = {}
  def addStuff(self, n, a, p = "000"):
    self.stuffName = n
    self.stuffAge = a
    self.stuffContact = p
    self.stuffId += 1
    self.stuff[self.stuffId] = [self.stuffName, self.stuffAge, self.stuffContact]
    print("Stuff with ID",self.stuffId,"is created")
  def getStuffById(self, n):
      temp = f"Staff ID: {n}\nName: {self.stuff[n][0]}\nAge: {self.stuff[n][1]}\nPhone no.: {self.stuff[n][2]}"
      return temp
  def addGuest(self, n, a, p):
    self.guestName = n
    self.guestAge = a
    self.guestContact = p
    self.guestId += 1
    self.guest[self.guestId] = [self.guestName, self.guestAge, self.guestContact]
    print("Guest with ID",self.guestId,"is created")
  def getGuestById(self, n):
    temp = f"Guest ID: {n}\nName: {self.guest[n][0]}\nAge: {self.guest[n][1]}\nPhone no.: {self.guest[n][2]}"
    return temp
  def allStaffs(self):
    for k,v in self.stuff.items():
      print(f"Staff ID: {k} Name: {v[0]} Age: {v[1]} Phone no: {v[2]}")
  def allGuest(self):
    for k,v in self.guest.items():
      print(f"Staff ID: {k} Name: {v[0]} Age: {v[1]} Phone no: {v[2]}")
h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest("Carol",35,"123")
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, "431")
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Staff With ID 1 is added
# =================================
# Staff ID: 1
# Name: Adam
# Age: 26
# Phone no.: 000
# =================================
# Guest With ID 1 is created
# =================================
# Guest ID: 1
# Name: Carol
# Age: 35
# Phone no.: 123
# =================================
# Guest With ID 2 is created
# =================================
# Guest ID: 2
# Name: Dianal
# Age: 32
# Phone no.: 431
# =================================
# All Staffs:
# Number of Staff: 1
# Staff ID: 1 Name: Adam Age: 26 Phone no: 000
# =================================
# All Guest:
# Number of Guest: 2
# Guest ID: 1 Name: Carol Age: 35 Phone no.: 123
# Guest ID: 2 Name: Dianal Age: 32 Phone no.: 431
# Out:
# Stuff with ID 1 is created
# =================================
# Staff ID: 1
# Name: Adam
# Age: 26
# Phone no.: 000
# =================================
# Guest with ID 1 is created
# =================================
# Guest ID: 1
# Name: Carol
# Age: 35
# Phone no.: 123
# =================================
# Guest with ID 2 is created
# =================================
# Guest ID: 2
# Name: Diana
# Age: 32
# Phone no.: 431
# =================================
# Staff ID: 1 Name: Adam Age: 26 Phone no: 000
# =================================
# Staff ID: 1 Name: Carol Age: 35 Phone no: 123
# Staff ID: 2 Name: Diana Age: 32 Phone no: 431

# %%
#Task 23
class Author:
  def __init__(self, n = "df"):
    self.name = n
    self.books = {}
  def addBook(self, n, t):
    if self.name == "df":
      print("A book can not be added without author name")
    else:
      if t not in self.books:
        self.books[t] = [n]
      else:
        self.books[t].append(n)
  def setName(self, n):
    self.name = n
  def printDetail(self):
    count = 0
    for v in self.books.values():
      count += len(v)
    print("Number of Book(s):",count)
    print("Author Name:",self.name)
    for k,v in self.books.items():
      print(k + ": ", end = '')
      for i in range(len(v)):
        if i == len(v)-1:
          print(v[i])
        else:
          print(v[i], end = ", ")
a1 = Author()
print("=================================")
a1.addBook("Ice","Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# =================================
# A book can not be added without author name
# =================================
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# =================================
# =================================
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# =================================
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon, Ireena
# Horror: Megher Upor Bari
# =================================
# Out:
# =================================
# A book can not be added without author name
# =================================
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# =================================
# =================================
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# =================================
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon, Ireena
# Horror: Megher Upor Bari
# =================================

# %%
#Task 24
class Hospital:
  def __init__(self, n):
    self.hospitalName = n
    self.doctor = {}
    self.patients = {}
  def addDoctor(self, d):
    self.doctor[d.docId] = [d.docName, d.speciality]
  def getDoctorByID(self, i):
    temp = f"Doctor's ID: {i}\nName: {self.doctor[i][0]}\nSpeciality: {self.doctor[i][1]}"
    return temp
  def addPatient(self, p):
    self.patients[p.patientId] = [p.patientName, p.age, p.contact]
  def getPatientByID(self, i):
     temp = f"Patient's ID: {i}\nName: {self.patients[i][0]}\nAge: {self.patients[i][1]}\nPhone No.: {self.patients[i][2]}"
     return temp
  def allDoctors(self):
    print("All Doctors:")
    print("Number of Doctors:",len(self.doctor))
    print(self.doctor)
  def allPatients(self):
    print("All Patients:")
    print("Number of Patients:", len(self.patients))
    print(self.patients)
class Doctor:
  def __init__(self, i, d, n, s):
    self.docId = i
    self.doc = d
    self.docName = n
    self.speciality = s
class Patient:
  def __init__(self, i, p, n, a, c):
    self.patientId = i
    self.patient = p
    self.patientName = n
    self.age = a
    self.contact = c
h = Hospital("Evercare")
d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
h.addDoctor(d1)
print("=================================")
print(h.getDoctorByID("1d"))
print("=================================")
p1 = Patient("1p","Patient", "Kashem Ahmed", 35, 12345)
h.addPatient(p1)
print("=================================")
print(h.getPatientByID("1p"))
print("=================================")
p2 = Patient ("2p","Patient", "Tanina Haque", 26, 33456)
h.addPatient(p2)
print("=================================")
print(h.getPatientByID("2p"))
print("=================================")
h.allDoctors()
h.allPatients()
# =================================
# Doctor's ID: 1d
# Name: Samar Kumar
# Speciality: Neurologist
# =================================
# =================================
# Patient's ID: 1p
# Name: Kashem Ahmed
# Age: 35
# Phone no.: 12345
# =================================
# =================================
# Patient's ID: 2p
# Name: Tanina Haque
# Age: 26
# Phone no.: 33456
# =================================
# All Doctors:
# Number of Doctors: 1
# {'1d': ['Samar Kumar', 'Neurologist']}
# All Patients:
# Number of Patients: 2
# {'1p': ['Kashem Ahmed', 35, 12345], '2p': ['Tanina Haque', 26, 33456]}
# Out:
# =================================
# Doctor's ID: 1d
# Name: Samar Kumar
# Speciality: Neurologist
# =================================
# =================================
# Patient's ID: 1p
# Name: Kashem Ahmed
# Age: 35
# Phone No.: 12345
# =================================
# =================================
# Patient's ID: 2p
# Name: Tanina Haque
# Age: 26
# Phone No.: 33456
# =================================
# All Doctors:
# Number of Doctors: 1
# {'1d': ['Samar Kumar', 'Neurologist']}
# All Patients:
# Number of Patients: 2
# {'1p': ['Kashem Ahmed', 35, 12345], '2p': ['Tanina Haque', 26, 33456]}

# %%
#Task 25
class Vaccine:
  def __init__(self, n, c, d):
    self.vaccineName = n
    self.country = c
    self.days = d
class Person:
  def __init__(self, n, a, p = "General Citizen"):
    self.personName = n
    self.age = a
    self.proff = p
    self.vaccine = []
    self.firstDose = 0
    self.secondDose = 0
  def pushVaccine(self, n, d = "1st dose"):
    if self.age >= 25 or (self.age < 25 and self.proff == "Student"):
      if d == "1st dose":
        self.vaccine.append(n)
        self.firstDose = 1
        print(d, "done for",self.personName)
      elif d == "2nd Dose" and n.vaccineName == self.vaccine[0].vaccineName:
        self.secondDose = 1
        print(d,"done for",self.personName)
      else:
        print("Sorry",self.personName + ",","you can't take 2 different vaccines")
    else:
      print("Sorry",self.personName + ",","Minimmum age for taking vaccine is 25 years now")
  def showDetail(self):
    print("Name:",self.personName,"Age:",self.age,"Type:",self.proff)
    print("Vaccine name:",self.vaccine[0].vaccineName)
    print(f"1st dose: {'Given' if self.firstDose == 1 else 'Not Given'}")
    #print(f"2nd Dose: {'Given' if self.secondDose == 1 else 'Please come after '+str(self.vaccine[0].days)+' days'}")
    print(f"2nd Dose: {'Given' if self.secondDose == 1 else f'Please come after {self.vaccine[0].days} days'}")
astra = Vaccine("AstraZeneca", "UK", 60)
modr = Vaccine("Moderna", "UK", 30)
sin = Vaccine("Sinopharm", "China", 30)
p1 = Person("Bob", 21, "Student")
print("=================================")
p1.pushVaccine(astra)
print("=================================")
p1.showDetail()
print("=================================")
p1.pushVaccine(sin, "2nd Dose")
print("=================================")
p1.pushVaccine(astra, "2nd Dose")
print("=================================")
p1.showDetail()
print("=================================")
p2 = Person("Carol", 23, "Actor")
print("=================================")
p2.pushVaccine(sin)
print("=================================")
p3 = Person("David", 34)
print("=================================")
p3.pushVaccine(modr)
print("=================================")
p3.showDetail()
print("=================================")
p3.pushVaccine(modr, "2nd Dose")
# =================================
# 1st dose done for Bob
# =================================
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Please come after 60 days
# =================================
# Sorry Bob, you can’t take 2 different vaccines
# =================================
# 2nd dose done for Bob
# =================================
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Given
# =================================
# =================================
# Sorry Carol, Minimum age for taking vaccines is
# 25 years now.
# =================================
# =================================
# 1st dose done for David
# =================================
# Name: David Age: 34 Type: General Citizen
# Vaccine name: Moderna
# 1st dose: Given
# 2nd dose: Please come after 30 days
# =================================
# 2nd dose done for David
# Out:
# =================================
# 1st dose done for Bob
# =================================
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd Dose: Please come after 60 days
# =================================
# Sorry Bob, you can't take 2 different vaccines
# =================================
# 2nd Dose done for Bob
# =================================
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd Dose: Given
# =================================
# =================================
# Sorry Carol, Minimmum age for taking vaccine is 25 years now
# =================================
# =================================
# 1st dose done for David
# =================================
# Name: David Age: 34 Type: General Citizen
# Vaccine name: Moderna
# 1st dose: Given
# 2nd Dose: Please come after 30 days
# =================================
# 2nd Dose done for David

# %%
class QuizA:
  def __init__(self):
    self.x = 3
    self.y = 5
    self.sum = 0
    self.c = 5
  def methodA(self,x):
    self.y = x + self.sum
    self.sum = x + self.y
    print(self.x, self.y, self.sum)
  def methodB(self, a):
    y = 3
    a.sum = self.x + self.sum
    self.c = y + self.c
    self.sum = a.x + self.c
    print(self.x, self.c, self.sum)
a = QuizA()
b = QuizA()
a.methodB(b)
b.methodA(b.sum)
b.methodA(a.y)
# Out:
# 3 8 11
# 3 6 9
# 3 14 19
